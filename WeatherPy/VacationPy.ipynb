# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/keniaoquendo/Desktop/Data_Analytics/UCI-VIRT-DATA-PT-09-2023-U-LOLC/python-api-challenge/WeatherPy/VacationPy.ipynb Cell 1 line 2
#       <a href='vscode-notebook-cell:/Users/keniaoquendo/Desktop/Data_Analytics/UCI-VIRT-DATA-PT-09-2023-U-LOLC/python-api-challenge/WeatherPy/VacationPy.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> # Dependencies and Setup
# ----> <a href='vscode-notebook-cell:/Users/keniaoquendo/Desktop/Data_Analytics/UCI-VIRT-DATA-PT-09-2023-U-LOLC/python-api-challenge/WeatherPy/VacationPy.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import hvplot.pandas
#       <a href='vscode-notebook-cell:/Users/keniaoquendo/Desktop/Data_Analytics/UCI-VIRT-DATA-PT-09-2023-U-LOLC/python-api-challenge/WeatherPy/VacationPy.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import pandas as pd
# ...

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../WeatherPy/Starter_Code 9/output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         faya  18.3851   42.4509     22.06        35          21
# 1        1      farsund  58.0948    6.8047     13.30       100           0
# 2        2  new norfolk -42.7826  147.0587     11.72        58          12
# 3        3    jamestown  42.0970  -79.2353      5.77        77         100
# 4        4      lanzhou  36.0564  103.7922     14.53        48          59
#
#    Wind Speed Country        Date
# 0        2.60      SA  1666108228
# 1        7.65      NO  1666108228
# 2        1.34      AU  1666108230
# 3        9.77      US  1666107934
# 4        1.20      CN  1666108230

# %%
# Configure the map plot
# YOUR CODE HERE
longitude= city_data_df["Lng"]
Latitude= city_data_df["Lat"]
Humidity= city_data_df["Humidity"]

map_plot =city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 0.05,
    color = "City"
)

# Display the map
# YOUR CODE HERE
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Country        object
# Date            int64
# dtype: object

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE
ideal_weather_df = city_data_df.loc[(city_data_df['Humidity'] <= int('100')) & 
                         (city_data_df['Max Temp'] <= float('28')) & 
                         (city_data_df['Wind Speed'] <= float('5'))&
                         (city_data_df['Cloudiness']== int (0))]

# Drop any rows with null values
ideal_weather_df.isnull().sum()
#THERE ARE NO NULL VALUES IN MY DATA FRAME
# Display sample data
ideal_weather_df.head(20)
# Out:
#      City_ID                City      Lat       Lng  Max Temp  Humidity  \
# 45        45               kapaa  22.0752 -159.3190     22.99        84
# 51        51                hilo  19.7297 -155.0900     26.27        83
# 63        63               banda  25.4833   80.3333     24.62        52
# 81        81       makakilo city  21.3469 -158.0858     21.66        81
# 83        83           esperance -33.8667  121.9000     11.24        87
# 90        90        saint george  37.1041 -113.5841     13.33        44
# 96        96             zhangye  38.9342  100.4517     11.11        16
# 115      115          cedar city  37.6775 -113.0619     14.11        49
# 121      121             lichuan  30.3000  108.8500      9.72        77
# 128      128       half moon bay  37.4636 -122.4286     19.71        86
# 141      141             brenham  30.1669  -96.3977     14.47        40
# 146      146  puerto del rosario  28.5004  -13.8627     24.86        73
# ...

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df= ideal_weather_df[['City','Country','Lat','Lng','Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name']= ""

# Display sample data
hotel_df.head(15)
# Out:
#                    City Country      Lat       Lng  Humidity Hotel Name
# 45                kapaa      US  22.0752 -159.3190        84
# 51                 hilo      US  19.7297 -155.0900        83
# 63                banda      IN  25.4833   80.3333        52
# 81        makakilo city      US  21.3469 -158.0858        81
# 83            esperance      AU -33.8667  121.9000        87
# 90         saint george      US  37.1041 -113.5841        44
# 96              zhangye      CN  38.9342  100.4517        16
# 115          cedar city      US  37.6775 -113.0619        49
# 121             lichuan      CN  30.3000  108.8500        77
# 128       half moon bay      US  37.4636 -122.4286        86
# 141             brenham      US  30.1669  -96.3977        40
# 146  puerto del rosario      ES  28.5004  -13.8627        73
# 152             kahului      US  20.8947 -156.4700        60
# 159           geraldton      AU -28.7667  114.6000        88
# ...

# %%
# Set parameters to search for a hotel
categories= "accommodation.hotel"

#set parameters for the type of search
radius = 10000
params = {
    "categories": categories,
    "apiKey": geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude= ideal_weather_df.loc[index,'Lat']
    longitude= ideal_weather_df.loc[index,'Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
   
    # Convert the API response to JSON format
    name_address = name_address.json
    
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        #If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 37
#      35 # Grab the first hotel from the results and store the name in the hotel_df DataFrame
#      36 try:
# ---> 37     hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
#      38 except (KeyError, IndexError):
#      39     #If no hotel is found, set the hotel name as "No hotel found".
#      40     hotel_df.loc[index, "Hotel Name"] = "No hotel found"
#
# TypeError: 'method' object is not subscriptable

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE

# Display the map
# YOUR CODE HERE
